# %%
import json
import csv

# %%
# Open the JSON file
with open('data.json') as json_file:
    data = json.load(json_file)

# %%
# Extract the data from the JSON file
fields = data['fields']
mar = data['markers']

# %%
# Open the CSV file for writing
with open('data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the header row
    writer.writerow(['name', 'owner', 'phone', 'website', 'email', 'logo', 'street', 'city', 'zip_code'])
    
    # Write the data rows
    for i in range(0,433):
        data = mar[i]
        
        logo_ = data['15']
        print(logo_)
        if logo_ is not None:
            logo_ = f"https://admin.fitness-classification.ch/{data['15']}"
        else:
            logo_ = None
        
        row = [
            data["2"],
            data["5"],
            data["7"],
            data["11"],
            data["8"],
            logo_,
            data["6"],
            data["10"],
            data["9"]
        ]
        writer.writerow(row)

print("CSV file created successfully!")
# Out:
# /storage/media/327/624c232f71f64.jpg
# /storage/media/233/624c18ef5e355.png
# /storage/media/240/624c19c7bbab6.png
# /storage/media/222/624c17d6903f2.jpg
#
#
# /storage/media/412/62725da3160c1.jpg
#
#
#
# /storage/media/185/624b20d591feb.jpg
#
#
#
#
#
# /storage/media/170/624b1f6e4941d.jpg
#
# /storage/media/276/624c1dd3b7ff1.png
#
#
# /storage/media/84/624b10a4cc407.png
# /storage/media/118/624b1770e1338.png
# /storage/media/346/624c24e668350.jpg
#
#
# /storage/media/100/624b13e6d4544.jpg
#
# /storage/media/237/624c1972ea07a.jpg
#
# /storage/media/105/624b14d840a9b.jpg
#
#
#
#
# /storage/media/280/624c1e246fcb3.jpg
# /storage/media/403/624c29c20638d.jpg
# /storage/media/493/63e23cf576253.png
#
#
# /storage/media/360/624c2624cb809.jpg
# /storage/media/355/624c25bfa7a4a.png
#
#
#
#
#
#
#
#
# /storage/media/189/624b210cde707.png
#
# /storage/media/148/624b1b9380f19.png
# /storage/media/430/62b98acb1febc.jpg
# /storage/media/5/622b4e6da7d92.png
# /storage/media/201/624c155710dd9.png
# ...

# %%
# Name of the Gym
# Logo
# Adresse
# Website
# Telefon
# Email

# %%
# Street: Walzmühlestrasse
# House number: 50
# Postal code/ZIP code: 8500
# City: Frauenfeld

# %%
for i in range(0,5):
    data = mar[i]
    
    name = data["2"]
    owner = data["5"]
    
    phone = data["7"]
    website = data["11"]
    email = data["8"]
    
    logo = f"https://www.sfgv.ch{data['15']}"
    
    street = data["6"]
    city = data["10"]
    zip_code = data["9"]
    
    # print(name)
    # print(owner)
    # print(phone)
    # print(website)
    # print(email)
    # print(logo)
    # print(street)
    # print(city)
    # print(zip_code)
    # print("----------------")

# %%
# Define the CSV file name
csv_file = 'data.csv'

# Write the data to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the header row
    writer.writerow(fields)
    
    # Write the data rows
    for key, value in markers.items():
        writer.writerow([key, value])

print("CSV file created successfully!")

# %%
import csv

# Assuming 'mar' is your list of dictionaries
mar = [...]  # replace with your actual data

# Define the CSV file name
csv_file = 'data.csv'

# Define the field names for the CSV file
fieldnames = ['name', 'owner', 'phone', 'website', 'email', 'logo', 'street', 'city', 'zip_code']

# Write the data to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.DictWriter(file, fieldnames=fieldnames)
    
    # Write the header row
    writer.writeheader()
    
    # Write the data rows
    for i in range(0,5):
        data = mar[i]
        logo = 'None' if data['15'] is None else f"https://admin.fitness-classification.ch/{data['15']}"
        
        row = {
            'name': data["2"],
            'owner': data["5"],
            'phone': data["7"],
            'website': data["11"],
            'email': data["8"],
            logo,
            'street': data["6"],
            'city': data["10"],
            'zip_code': data["9"]
        }
        
        writer.writerow(row)

print("CSV file created successfully!")

# %%
# Name of the Gym
# Logo
# Adresse
# Website
# Telefon
# Email

# %%
# Extract the data from the JSON file
fields = data['fields']
markers = data['markers']

# Define the CSV file name
csv_file = 'data.csv'

# Write the data to the CSV file
with open(csv_file, 'w', newline='') as file:
    writer = csv.writer(file)
    
    # Write the header row
    writer.writerow(fields)
    
    # Write the data rows
    for key, value in markers.items():
        writer.writerow([key, value])

print("CSV file created successfully!")
